# %%
# Hier sind die dependencies, nur ausführen wenn irgendwas fehlt!
# !pip install pandas
# !pip install xlrd
# !pip install matplotlib
# !pip install seaborn

# %%
from read_data_test import IliasDataPlotter, ExamDataPlotter
# Out:
# C:\Users\patri\Anaconda3\envs\mcts\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
filename = "bsp.xlsx"
ilias_results = IliasDataPlotter(filename)

exam_filename = "SoSe 18.csv"
exam_results = ExamDataPlotter(exam_filename, max_points=50)

# plot settings:
color = "Blues"
plot_size = (12, 7)

# %%
ilias_results.plot_result()

# %%
ilias_results.plot_used_time()

# %%
exam_results.boxplot(size=plot_size, color=color)

# %%
exam_results.violinplot(size=plot_size, color=color)
