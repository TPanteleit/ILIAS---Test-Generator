# %%
# Hier sind die dependencies, zum Ausführen falls irgendwas fehlt.
# !pip install pandas
# !pip install xlrd
# !pip install matplotlib
# !pip install seaborn

# %%
from read_data_test import PaperDataPlotter
# Out:
# C:\Users\patri\Anaconda3\envs\mcts\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
pdp = PaperDataPlotter("raw_data_paper.xlsx")

# Hier sind die plot settings:
pdp.font_size = 2
pdp.color = "Blues"
pdp.size = (24, 12)

# %%
# SoSe18
pdp.boxplot(0)
# Out:
# C:\Users\patri\Anaconda3\envs\mcts\lib\site-packages\numpy\lib\function_base.py:3405: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %%
#WiSe1819
pdp.boxplot(1)
# Out:
# C:\Users\patri\Anaconda3\envs\mcts\lib\site-packages\numpy\lib\function_base.py:3405: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %%
#SoSe19
pdp.size=(24, 12)
pdp.boxplot(2)
# Out:
# C:\Users\patri\Anaconda3\envs\mcts\lib\site-packages\numpy\lib\function_base.py:3405: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
#WiSe1920
pdp.boxplot(3)
# Out:
# C:\Users\patri\Anaconda3\envs\mcts\lib\site-packages\numpy\lib\function_base.py:3405: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
#Klausur
pdp.boxplot_p(4)
# Out:
# C:\Users\patri\Anaconda3\envs\mcts\lib\site-packages\numpy\lib\function_base.py:3405: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
#Bonuspunkte
pdp.boxplot_bp(5)
# Out:
# C:\Users\patri\Anaconda3\envs\mcts\lib\site-packages\numpy\lib\function_base.py:3405: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
